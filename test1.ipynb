# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %% [markdown]
# # Answer 17

# %%
data=pd.read_csv("Book1.csv")#Calculating the average salary of given dataset
average_salary = np.mean(data['Salary'])
print("average_salary =",average_salary)
# Out:
# average_salary = 59800.0

# %% [markdown]
# # Answer 18

# %%
Salary_filtering=data[data['Salary']>60000]
print(Salary_filtering)
# Out:
#    Name  Age  Gender  Salary Department
# 3  Emma   26  Female   62000         IT
# 4  Ryan   35    Male   72000    Finance

# %% [markdown]
# # Answer 19

# %%
plt.bar(data['Department'], data['Salary']) #plotting the bar graph of the employees and their salary(19)
plt.title('Bar graph of employees and their salary')
plt.xlabel('Department')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')
